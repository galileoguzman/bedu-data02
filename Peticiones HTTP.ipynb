# %%
import requests

# %%
response = requests.get('https://bedu.org')
print(response.status_code)
# Out:
# 200

# %%
print(response.content)
# Out:
# b'<!doctype html><html lang=es class="font-rubik leading-normal antialiased"><meta charset=utf-8><meta name=viewport content="width=device-width,initial-scale=1,shrink-to-fit=no"><link rel=apple-touch-icon sizes=180x180 href=/apple-touch-icon.png><link rel=icon type=image/png sizes=32x32 href=/favicon-32x32.png><link rel=icon type=image/png sizes=16x16 href=/favicon-16x16.png><link rel=manifest href=/site.webmanifest><title>Inicio | BEDU</title><meta name=language content="Spanish"><meta name=description content="Somos una comunidad de formaci\xc3\xb3n de talento que ofrece cursos de programaci\xc3\xb3n, cursos de negocios y cursos de ingl\xc3\xa9s en modalidad semipresencial."><link rel=canonical href=/><meta property="og:title" content="Inicio | BEDU"><meta property="og:type" content="website"><meta property="og:image" content="https://assets.bedu.org/images/hero-image.jpg"><meta property="og:image:secure_url" content="https://assets.bedu.org/images/hero-image.jpg"><meta property="
# ...
